# %% [markdown]
# <a href="https://colab.research.google.com/github/bloomfieldfong/TextMining-ImageRecognition/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 1
# Author: Michelle Anabel Bloomfield Fong
# Carné: 22000345
# Clase: Text Mining & Image Recognition

# %%
import cv2
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/ImageRecognition/rae.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## **`Ejercicio 1`**
#
#
# Desarrolle una funci ́on la cual reciba dos par ́ametros, una imagen y un entero llamado color, la
# funci ́on debe devolver una imagen la cual tenga activos los canales de color

# %%
## Problema1
## Devuelve una imagen la cual tenga activos los canales de color indicado
## Parametros de ingreso
## img = imagen 
## color = 	{1: azul, 2:verde, 3:rojo, 10:rojo y verde, 20:verde y azul, 30:azul y rojo}


def problema1(img, color):
	alto = img.shape[0]
	ancho = img.shape[1]
	lienzo = np.zeros((alto, ancho, 3))

	for i in range(0, alto):
		for j in range(0,ancho):
			pixel = img[i,j]
			red = pixel[0]
			blue = pixel[2]
			green = pixel[1]
      
			if color == 1:
				lienzo[i,j] = [blue,0,0]
			if color == 2: 
				lienzo[i,j] = [0,green,0]
			if color == 3:
				lienzo[i,j] = [0,0,red]
			if color == 10: 
				lienzo[i,j] = [0,green,red]
			if color == 20: 
				lienzo[i,j] = [blue,green,0]
			if color == 30: 
				lienzo[i,j] = [blue,0,red]
	cv2.imwrite("problema1.jpg", lienzo)
	lienzo = cv2.imread("problema1.jpg")
	lienzo = cv2.cvtColor(lienzo, cv2.COLOR_BGR2RGB)
	plt.imshow(lienzo)
	plt.show()

# %% [markdown]
# Pruebas de ejercicio 1

# %%
problema1(img, 1)

# %%
problema1(img, 2)

# %%
problema1(img, 3)

# %%
problema1(img, 10)

# %%
problema1(img, 20)

# %%
problema1(img, 30)

# %% [markdown]
# Import de imagenes para validacion de funciones

# %%
imagenazul_perro = cv2.imread('/content/drive/MyDrive/ImageRecognition/perro/perro_salida_gray_azul.jpg')
imagenazul_perro = cv2.cvtColor(imagenazul_perro, cv2.COLOR_BGR2RGB)

imagenrojo_perro = cv2.imread('/content/drive/MyDrive/ImageRecognition/perro/perro_salida_gray_rojo.jpg')
imagenrojo_perro = cv2.cvtColor(imagenrojo_perro, cv2.COLOR_BGR2RGB)

imagenverde_perro = cv2.imread('/content/drive/MyDrive/ImageRecognition/perro/perro_salida_gray_verde.jpg')
imagenverde_perro = cv2.cvtColor(imagenverde_perro, cv2.COLOR_BGR2RGB)

# %%
imagenazul_imagen1 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen1/imagen1_salida_gray_azul.jpg')
imagenazul_imagen1 = cv2.cvtColor(imagenazul_imagen1, cv2.COLOR_BGR2RGB)

imagenrojo_imagen1 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen1/imagen1_salida_gray_rojo.jpg')
imagenrojo_imagen1 = cv2.cvtColor(imagenrojo_imagen1, cv2.COLOR_BGR2RGB)

imagenverde_imagen1 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen1/imagen1_salida_gray_verde.jpg')
imagenverde_imagen1 = cv2.cvtColor(imagenverde_imagen1, cv2.COLOR_BGR2RGB)

# %%
imagenazul_imagen2 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen2/imagen2_salida_gray_azul.jpg')
imagenazul_imagen2 = cv2.cvtColor(imagenazul_imagen2, cv2.COLOR_BGR2RGB)

imagenrojo_imagen2 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen2/imagen2_salida_gray_rojo.jpg')
imagenrojo_imagen2 = cv2.cvtColor(imagenrojo_imagen2, cv2.COLOR_BGR2RGB)

imagenverde_imagen2 = cv2.imread('/content/drive/MyDrive/ImageRecognition/imagen2/imagen2_salida_gray_verde.jpg')
imagenverde_imagen2 = cv2.cvtColor(imagenverde_imagen2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## **`Ejercicio 2`**
#
# En el .zip del laboratorio se le compartio un conjunto de imagenes en escala de grises (imagen1,
# imagen2, perro) estas imagenes fueron creadas utilizando una escala de grises en 3D, cree una
# funci ́on que dadas las 3 imagenes se construya la imagen original a color

# %%
## Problema2
## Devuelve una imagen conjunta de 3 imagenes a escala de grises

def problema2(red, green, blue):

	alto = red.shape[0]
	ancho = red.shape[1]
	gris_ponderado = np.zeros((alto, ancho, 3))

	for i in range(0, alto):
		for j in range(0, ancho):
			red_pixel = red[i, j]
			green_pixel = green[i, j]
			blue_pixel = blue[i, j]

			blue_d = blue_pixel[2]
			green_d = green_pixel[1]
			red_d = red_pixel[0]

			gris_ponderado[i, j] = [blue_d, green_d ,red_d] 

	cv2.imwrite('problema2.jpg', gris_ponderado)
	gris_ponderado = cv2.imread("problema2.jpg")
	gris_ponderado = cv2.cvtColor(gris_ponderado, cv2.COLOR_BGR2RGB)
	plt.imshow(gris_ponderado)
	plt.show()

# %% [markdown]
# Pruebas de ejercicio 2

# %%
problema2(imagenrojo_perro, imagenverde_perro,imagenazul_perro )

# %%
problema2(imagenrojo_imagen1, imagenverde_imagen1, imagenazul_imagen1)

# %%
problema2(imagenrojo_imagen2, imagenverde_imagen2, imagenazul_imagen2)

# %% [markdown]
# ## **`Ejercicio 3`**
#
# Cree una funcion que dada una imagen cree una escala de grises en tres dimensiones, tome en
# cuenta que su funcion debe crear 3 imagenes como salida. Para entregar este ejercicio debe incluir
# una las imagenes que haya utilizado como prueba y el resultado de las misma.

# %%
def problema3(imagen):

	alto = imagen.shape[0]
	ancho = imagen.shape[1]

	gris_ponderado = np.zeros((alto, ancho, 3))
	gris_green = np.zeros((alto,ancho,1))
	gris_blue = np.zeros((alto,ancho,1))
	gris_red = np.zeros((alto,ancho,1))

	for i in range(0, alto):
		for j in range(0, ancho):
			pixel = imagen[i, j]

			gris_blue[i,j] = pixel[2]
			gris_green[i,j] = pixel[1]
			gris_red[i,j] = pixel[0]

			blue = pixel[2]
			green = pixel[1]
			red = pixel[0]

			gris_ponderado[i, j] = int(0.299*blue + 0.587*green + 0.114*red) 	
			
	print("\nEscala de grises en Rojo\n")
	cv2.imwrite('problema3_red.jpg', gris_red)
	gris_ponderado = cv2.imread("problema3_red.jpg")
	gris_ponderado = cv2.cvtColor(gris_ponderado, cv2.COLOR_BGR2RGB)
	plt.imshow(gris_ponderado)
	plt.show()

	print("\nEscala de grises en Verde\n")
	cv2.imwrite('problema3_green.jpg', gris_green)
	gris_ponderado = cv2.imread("problema3_green.jpg")
	gris_ponderado = cv2.cvtColor(gris_ponderado, cv2.COLOR_BGR2RGB)
	plt.imshow(gris_ponderado)
	plt.show()

	print("\nEscala de grises en Azul\n")
	cv2.imwrite('problema3_blue.jpg', gris_blue)
	gris_ponderado = cv2.imread("problema3_blue.jpg")
	gris_ponderado = cv2.cvtColor(gris_ponderado, cv2.COLOR_BGR2RGB)
	plt.imshow(gris_ponderado)
	plt.show()

# %% [markdown]
# Pruebas de ejercicio 3

# %%
problema3(img)
# Out:
# Escala de grises en Rojo
# Escala de grises en Verde
# Escala de grises en Azul

# %% [markdown]
# ## **`Ejercicio 4`**
#
# Cree una funcion que dada una imagen, muestre el histograma de cada canal de color y el de
# escala de grises (utilice un promedio aritmetico para su escala de grises, no puede usar funciones
# de opencv), sus histogramas deben incluir una l ́ınea vertical la cual muestre el valor de la media
# de la distribucion

# %%
def problema4(img):
	alto = img.shape[0]
	ancho = img.shape[1]

	gris_ponderado = np.zeros((alto, ancho, 3))

	for i in range(0, alto):
		for j in range(0, ancho):
			pixel = img[i, j]
			blue = pixel[2]
			green = pixel[1]
			red = pixel[0]
			gris_ponderado[i, j] = int(0.299*blue + 0.587*green + 0.114*red) 

	colores = ['Rojo', 'Azul', 'Verde']
	for i in range(0,3):
		print("Grafica de gris ponderado en color: "+str(colores[i]))
		plt.style.use('ggplot')
		plt.hist(gris_ponderado[i],bins=10)
		plt.axvline(gris_ponderado[i].mean(), color='k', linestyle='dashed', linewidth=1)
		plt.show()

# %%
problema4(img)
# Out:
# Grafica de gris ponderado en color: Rojo
# Grafica de gris ponderado en color: Azul
# Grafica de gris ponderado en color: Verde

# %% [markdown]
# ## **`Ejercicio 5`**
#
# Investigue en que consiste el enfoque de escala de grises ponderado, luego de esto implemente una
# funci on que dada una imagen, realice una escala de grises ponderada (notar que no existe una
# solucion  ́unica)

# %% [markdown]
# La escala de grises ponderada se enfoca en como el ojo percibe las intensidades de distintos colores, como hablabamos en clase, el verde es un color qe percibimos con mayor intensadad por el cual el calculo de la escala blanco y negro de una imagen se debe de realizar de una manera ponderada para detectar mejor la imagen.

# %%
def problema5(img):
	alto = img.shape[0]
	ancho = img.shape[1]

	gris_ponderado = np.zeros((alto, ancho, 3))

	for i in range(0, alto):
		for j in range(0, ancho):
			pixel = img[i, j]
			blue = pixel[2]
			green = pixel[1]
			red = pixel[0]
			gris_ponderado[i, j] = int(0.299*blue + 0.587*green + 0.114*red) 

	cv2.imwrite('problema5.jpg', gris_ponderado)
	gris_ponderado = cv2.imread("problema5.jpg")
	gris_ponderado = cv2.cvtColor(gris_ponderado, cv2.COLOR_BGR2RGB)
	plt.imshow(gris_ponderado)
	plt.show()

# %%
problema5(img)

# %% [markdown]
# ## **`Ejercicio 6`**
# Investigue brevemente en que consiste el espacio de color HSV y como se mapean colores a dicho
# espacio, para entregar este ejercicio puede hacerlo por medio de Markdown en el mismo Notebook
# donde trabajo los demas ejercicios

# %% [markdown]
# El modelo HSV (Hue, Saturation, Valor) es una medidad de escala de colores que se representa como un cono de colores. La manera en que estos colores se mapea es en el en eje vertical del cono se calcula el valor (representando la intensidad del color) la saturacion se calcula de manera vertica y el color se calcula por el medio de la rotación del circulo.
